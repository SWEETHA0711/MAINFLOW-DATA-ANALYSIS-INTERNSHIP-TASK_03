# %%
#importing libraries
import pandas as pd
import matplotlib.pyplot as plt

# %%
#loading the dataset
data=pd.read_csv("/content/householdtask3.csv")
data
# Out:
#     year  tot_hhs      own  own_wm  own_prop  own_wm_prop  prop_hhs   age  \
# 0   2008  1560859  1087580  574406      69.7         36.8     100.0  35.9
# 1   2008   185965    71256   39405      38.3         21.2      11.9  29.9
# 2   2008   312376   191470   48424      61.3         15.5      20.0  40.0
# 3   2008   312333   196203   84171      62.8         26.9      20.0  34.7
# 4   2008   312240   217657  141318      69.7         45.3      20.0  31.5
# ..   ...      ...      ...     ...       ...          ...       ...   ...
# 65  2020   352564   213893  119637      60.7         33.9      20.1  36.9
# 66  2020   350182   235256  141104      67.2         40.3      19.9  35.0
# 67  2020   351328   288779  187838      82.2         53.5      20.0  39.6
# 68  2020   329588   156459  107753      47.5         32.7      18.8  31.1
# 69  2020   388013   314154   38270      81.0          9.9      22.1  69.8
#
#     size  income  expenditure  eqv_income  eqv_exp
# ...

# %%
#displaying first 10 rows
data.head(10)
# Out:
#    year  tot_hhs      own  own_wm  own_prop  own_wm_prop  prop_hhs   age  \
# 0  2008  1560859  1087580  574406      69.7         36.8     100.0  35.9
# 1  2008   185965    71256   39405      38.3         21.2      11.9  29.9
# 2  2008   312376   191470   48424      61.3         15.5      20.0  40.0
# 3  2008   312333   196203   84171      62.8         26.9      20.0  34.7
# 4  2008   312240   217657  141318      69.7         45.3      20.0  31.5
# 5  2008   312336   229014  147658      73.3         47.3      20.0  35.3
# 6  2008   311574   253235  152835      81.3         49.1      20.0  39.3
# 7  2008   312761   194358   49448      62.1         15.8      20.0  38.7
# 8  2008   311973   206342   86390      66.1         27.7      20.0  36.1
# 9  2008   311840   194361  108065      62.3         34.7      20.0  33.0
#
#    size  income  expenditure  eqv_income  eqv_exp
# 0   2.7   46704        42394       26869    25132
# 1   2.6   23404        25270       14258    15824
# ...

# %%
print(f'no of rows:',data.shape[0])
print(f'no of columns :',data.shape[1])
# Out:
# no of rows: 70
# no of columns : 13

# %%
#checking for null values
data.isnull().sum()
# Out:
# year           0
# tot_hhs        0
# own            0
# own_wm         0
# own_prop       0
# own_wm_prop    0
# prop_hhs       0
# age            0
# size           0
# income         0
# expenditure    0
# eqv_income     0
# eqv_exp        0
# dtype: int64

# %%
#checking for duplicate rows
data.drop_duplicates()
# Out:
#     year  tot_hhs      own  own_wm  own_prop  own_wm_prop  prop_hhs   age  \
# 0   2008  1560859  1087580  574406      69.7         36.8     100.0  35.9
# 1   2008   185965    71256   39405      38.3         21.2      11.9  29.9
# 2   2008   312376   191470   48424      61.3         15.5      20.0  40.0
# 3   2008   312333   196203   84171      62.8         26.9      20.0  34.7
# 4   2008   312240   217657  141318      69.7         45.3      20.0  31.5
# ..   ...      ...      ...     ...       ...          ...       ...   ...
# 65  2020   352564   213893  119637      60.7         33.9      20.1  36.9
# 66  2020   350182   235256  141104      67.2         40.3      19.9  35.0
# 67  2020   351328   288779  187838      82.2         53.5      20.0  39.6
# 68  2020   329588   156459  107753      47.5         32.7      18.8  31.1
# 69  2020   388013   314154   38270      81.0          9.9      22.1  69.8
#
#     size  income  expenditure  eqv_income  eqv_exp
# ...

# %%
#visualize data using scatterplot
plt.scatter(data['year'],data['own'],color='purple')

#title of the plot
plt.title('scatterplot')

#label for the exes
plt.xlabel('year')
plt.ylabel('own')

#displaying the plot
plt.show()

# %%
#visualize data using lineplot
plt.plot(data['year'],color='orangered')
plt.plot(data['own'],color='green')

#setting legend
plt.legend(['year','own'])

#title of the plot
plt.title('lineplot')

#label for the axes
plt.xlabel('year')
plt.ylabel('own')

#displaying the plot
plt.show()

# %%
#visualize data using barchart
plt.bar(data['year'],data['own'],color='cyan')

#title of the chart
plt.title('bar chart')

#label for the axes
plt.xlabel('year')
plt.ylabel('own')

#displaying the plot
plt.show()

# %%
#visualize data using histogram
plt.hist(data['income'],color='magenta')

#title of the chart
plt.title('histogram')

#displaying the chart
plt.show()
